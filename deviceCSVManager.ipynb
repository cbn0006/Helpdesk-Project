# %% [markdown]
# # Work for James
#
# Goal: Create a CSV Manager that reads in 2 csvs (one current, and one being tested against the current one). Create a new column in the main spreadsheet that is "still exists". Check this column off if the

# %%
import pandas as pd

rawCSV = pd.read_csv('Current.csv')

rawCSV.head()
# Out:
#                                   Device ID     Device Name  \
# 0  48d6c61c105fd885722249d314e2c93d10e51079  pty246-wad0005
# 1  2f55387a1dc63d4ca50a0783a9fafb8a96b08e80     mobile-1-mg
# 2  855fb5f9c5c4ea47a298a71bfa4fe00a2b2f7828  fnc212-shawjo1
# 3  cdca41b0ee130c5034d108f092c348e782b9886f       cmr303-13
# 4  f9020d4259019f9590e51861f776365da8d97606     ejb0049-nbk
#
#         Device Category  Device Type Device Subtype      Discovery sources  \
# 0  Computers and Mobile  Workstation    Workstation  Defender for Endpoint
# 1  Computers and Mobile  Workstation    Workstation  Defender for Endpoint
# 2  Computers and Mobile  Workstation    Workstation  Defender for Endpoint
# 3  Computers and Mobile  Workstation    Workstation  Defender for Endpoint
# 4  Computers and Mobile  Workstation    Workstation  Defender for Endpoint
#
#            Domain                         AAD Device Id        First Seen  \
# 0  mmd.auburn.edu  d55773de-194e-4fc0-9343-50d8b339e3f6  11/14/2022 15:08
# ...

# %%
# Capture user input for file name

newFile = input("Please enter new file's name: ")
